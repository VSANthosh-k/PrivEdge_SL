# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import socket, struct
import imblearn
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from imblearn.under_sampling import NearMiss
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder, StandardScaler, PowerTransformer
from sklearn.decomposition import PCA

# %%
import socket
import threading
import pickle
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, Input
from keras.optimizers import Adam
import tensorflow as tf

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
benign = pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.benign.csv")
g_c=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.gafgyt.combo.csv")
g_j=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.gafgyt.junk.csv")
g_s=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.gafgyt.scan.csv")
g_t=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.gafgyt.tcp.csv")
g_u=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.gafgyt.udp.csv")
m_a=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.mirai.ack.csv")
m_sc=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.mirai.scan.csv")
m_sy=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.mirai.syn.csv")
m_u=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.mirai.udp.csv")
m_u_p=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/1.mirai.udpplain.csv")

benign9 = pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.benign.csv")
g_c9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.gafgyt.combo.csv")
g_j9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.gafgyt.junk.csv")
g_s9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.gafgyt.scan.csv")
g_t9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.gafgyt.tcp.csv")
g_u9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.gafgyt.udp.csv")
m_a9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.mirai.ack.csv")
m_sc9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.mirai.scan.csv")
m_sy9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.mirai.syn.csv")
m_u9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.mirai.udp.csv")
m_u_p9=pathlib.Path("/content/drive/MyDrive/scopus/N-BaIoT dataset/9.mirai.udpplain.csv")

# %%
# Load your data
benign = pd.read_csv(benign)
g_c=pd.read_csv(g_c)
g_j=pd.read_csv(g_j)
g_s=pd.read_csv(g_s)
g_t=pd.read_csv(g_t)
g_u=pd.read_csv(g_u)
m_a=pd.read_csv(m_a)
m_sc=pd.read_csv(m_sc)
m_sy=pd.read_csv(m_sy)
m_u=pd.read_csv(m_u)
m_u_p=pd.read_csv(m_u_p)

benign9 = pd.read_csv(benign9)
g_c9=pd.read_csv(g_c9)
g_j9=pd.read_csv(g_j9)
g_s9=pd.read_csv(g_s9)
g_t9=pd.read_csv(g_t9)
g_u9=pd.read_csv(g_u9)
m_a9=pd.read_csv(m_a9)
m_sc9=pd.read_csv(m_sc9)
m_sy9=pd.read_csv(m_sy9)
m_u9=pd.read_csv(m_u9)
m_u_p9=pd.read_csv(m_u_p9)

# %%
benign=benign.sample(frac=0.35,replace=False)
g_c=g_c.sample(frac=0.25,replace=False)
g_j=g_j.sample(frac=0.5,replace=False)
g_s=g_s.sample(frac=0.5,replace=False)
g_t=g_t.sample(frac=0.15,replace=False)
g_u=g_u.sample(frac=0.15,replace=False)
m_a=m_a.sample(frac=0.15,replace=False)
m_sc=m_sc.sample(frac=0.15,replace=False)
m_sy=m_sy.sample(frac=0.15,replace=False)
m_u=m_u.sample(frac=0.08,replace=False)
m_u_p=m_u_p.sample(frac=0.17,replace=False)

benign9=benign9.sample(frac=0.35,replace=False)
g_c9=g_c9.sample(frac=0.25,replace=False)
g_j9=g_j9.sample(frac=0.5,replace=False)
g_s9=g_s9.sample(frac=0.5,replace=False)
g_t9=g_t9.sample(frac=0.15,replace=False)
g_u9=g_u9.sample(frac=0.15,replace=False)
m_a9=m_a9.sample(frac=0.15,replace=False)
m_sc9=m_sc9.sample(frac=0.15,replace=False)
m_sy9=m_sy9.sample(frac=0.15,replace=False)
m_u9=m_u9.sample(frac=0.08,replace=False)
m_u_p9=m_u_p9.sample(frac=0.17,replace=False)

# %%
benign['type']='benign'
m_u['type']='mirai_udp'
g_c['type']='gafgyt_combo'
g_j['type']='gafgyt_junk'
g_s['type']='gafgyt_scan'
g_t['type']='gafgyt_tcp'
g_u['type']='gafgyt_udp'
m_a['type']='mirai_ack'
m_sc['type']='mirai_scan'
m_sy['type']='mirai_syn'
m_u_p['type']='mirai_udpplain'

benign9['type']='benign'
m_u9['type']='mirai_udp'
g_c9['type']='gafgyt_combo'
g_j9['type']='gafgyt_junk'
g_s9['type']='gafgyt_scan'
g_t9['type']='gafgyt_tcp'
g_u9['type']='gafgyt_udp'
m_a9['type']='mirai_ack'
m_sc9['type']='mirai_scan'
m_sy9['type']='mirai_syn'
m_u_p9['type']='mirai_udpplain'

data=pd.concat([benign,m_u,g_c,g_j,g_s,g_t,g_u,m_a,m_sc,m_sy,m_u_p,benign9,m_u9,g_c9,g_j9,g_s9,g_t9,g_u9,m_a9,m_sc9,m_sy9,m_u_p9],
               axis=0, sort=False, ignore_index=True)

# %%
data.shape
# Out:
# (322007, 116)

# %%
data.type.unique()
# Out:
# array(['benign', 'mirai_udp', 'gafgyt_combo', 'gafgyt_junk',
#        'gafgyt_scan', 'gafgyt_tcp', 'gafgyt_udp', 'mirai_ack',
#        'mirai_scan', 'mirai_syn', 'mirai_udpplain'], dtype=object)

# %%
#how many instances of each class
data.groupby('type')['type'].count()
# Out:
# type
# benign            24177
# gafgyt_combo      29780
# gafgyt_junk       28240
# gafgyt_scan       29210
# gafgyt_tcp        28532
# gafgyt_udp        31328
# mirai_ack         31407
# mirai_scan        22704
# mirai_syn         36758
# mirai_udp         31580
# mirai_udpplain    28291
# Name: type, dtype: int64

# %%
#shuffle rows of dataframe
sampler=np.random.permutation(len(data))
data=data.take(sampler)
data.head()
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 6466            1.000000       60.000001            0.000035
# 313163         71.808710      404.291170        51543.428265
# 307732         99.098462      539.163878         7092.667081
# 80812           1.000000       60.000000            0.000000
# 222657         72.901290       74.020851            0.499986
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 6466            1.000027       60.001022            0.038818
# 313163        125.281699      424.867801        47116.181526
# 307732        177.665688      511.709702        19081.745825
# 80812           1.000000       60.000000            0.000000
# 222657         83.915628       74.060985            1.470257
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 6466            1.029957       61.105252           40.777976
# 313163        422.828931      417.754720        48742.392108
# 307732        558.049103      450.544525        40388.210513
# 80812           1.000000       60.000000            0.000000
# 222657        120.945040       74.462130          207.762615
#
#         MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  HpHp_L0.1_pcc  \
# 6466              2.358867  ...         -1.320000e-33  -2.060000e-21
# 313163         1449.489396  ...          0.000000e+00   0.000000e+00
# 307732         5607.736776  ...          0.000000e+00   0.000000e+00
# 80812             1.000000  ...          0.000000e+00   0.000000e+00
# 222657         1042.124205  ...          0.000000e+00   0.000000e+00
#
#         HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 6466             6.687580             60.0    6.740000e-07
# 313163        1223.457309            554.0    4.764555e-05
# 307732       26621.626005            554.0    5.658110e-05
# 80812            1.000000             60.0    0.000000e+00
# 222657           2.898455             74.0    9.536743e-07
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 6466               84.852814       6.430000e-13          -1.940000e-29
# 313163            554.000000       2.270099e-09           0.000000e+00
# 307732            554.000000       3.201421e-09           0.000000e+00
# 80812              60.000000       0.000000e+00           0.000000e+00
# 222657             74.000000       9.094947e-13           0.000000e+00
#
#         HpHp_L0.01_pcc            type
# 6466     -4.270000e-17          benign
# 313163    0.000000e+00  mirai_udpplain
# 307732    0.000000e+00  mirai_udpplain
# 80812     0.000000e+00      gafgyt_tcp
# 222657    0.000000e+00     gafgyt_scan
#
# [5 rows x 116 columns]

# %%
Y=data['type']

# %%
#drop labels from training dataset
X=data.drop(columns='type')
X.head()
# Out:
#         MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  \
# 6466            1.000000       60.000001            0.000035
# 313163         71.808710      404.291170        51543.428265
# 307732         99.098462      539.163878         7092.667081
# 80812           1.000000       60.000000            0.000000
# 222657         72.901290       74.020851            0.499986
#
#         MI_dir_L3_weight  MI_dir_L3_mean  MI_dir_L3_variance  \
# 6466            1.000027       60.001022            0.038818
# 313163        125.281699      424.867801        47116.181526
# 307732        177.665688      511.709702        19081.745825
# 80812           1.000000       60.000000            0.000000
# 222657         83.915628       74.060985            1.470257
#
#         MI_dir_L1_weight  MI_dir_L1_mean  MI_dir_L1_variance  \
# 6466            1.029957       61.105252           40.777976
# 313163        422.828931      417.754720        48742.392108
# 307732        558.049103      450.544525        40388.210513
# 80812           1.000000       60.000000            0.000000
# 222657        120.945040       74.462130          207.762615
#
#         MI_dir_L0.1_weight  ...  HpHp_L0.1_radius  HpHp_L0.1_covariance  \
# 6466              2.358867  ...      1.020000e-12         -1.320000e-33
# 313163         1449.489396  ...      1.164153e-10          0.000000e+00
# 307732         5607.736776  ...      2.968591e-09          0.000000e+00
# 80812             1.000000  ...      0.000000e+00          0.000000e+00
# 222657         1042.124205  ...      0.000000e+00          0.000000e+00
#
#         HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 6466    -2.060000e-21           6.687580             60.0    6.740000e-07
# 313163   0.000000e+00        1223.457309            554.0    4.764555e-05
# 307732   0.000000e+00       26621.626005            554.0    5.658110e-05
# 80812    0.000000e+00           1.000000             60.0    0.000000e+00
# 222657   0.000000e+00           2.898455             74.0    9.536743e-07
#
#         HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 6466               84.852814       6.430000e-13          -1.940000e-29
# 313163            554.000000       2.270099e-09           0.000000e+00
# 307732            554.000000       3.201421e-09           0.000000e+00
# 80812              60.000000       0.000000e+00           0.000000e+00
# 222657             74.000000       9.094947e-13           0.000000e+00
#
#         HpHp_L0.01_pcc
# 6466     -4.270000e-17
# 313163    0.000000e+00
# 307732    0.000000e+00
# 80812     0.000000e+00
# 222657    0.000000e+00
#
# [5 rows x 115 columns]

# %%
X.shape
# Out:
# (322007, 115)

# %%
Y.shape
# Out:
# (322007,)

# %%
Y.head()
# Out:
# 6466              benign
# 313163    mirai_udpplain
# 307732    mirai_udpplain
# 80812         gafgyt_tcp
# 222657       gafgyt_scan
# Name: type, dtype: object

# %% [markdown]
# **ANOVA Feature selection method**

# %%
from sklearn.feature_selection import SelectKBest, SelectPercentile, chi2, f_classif, mutual_info_classif
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# Apply SelectKBest with the ANOVA F-test
k = 60  # Define the number of top features to select
selector = SelectKBest(score_func=f_classif, k=k)
X_selected_A = selector.fit_transform(X,Y)

# %%
# Get selected feature indices and scores
selected_indices = selector.get_support(indices=True)
selected_feature_names = X.columns[selected_indices]
selected_scores = selector.scores_[selected_indices]

# %%
# Display selected features and their ANOVA F-scores
print("Selected top-k features based on ANOVA F-test:")
for feature, score in zip(selected_feature_names, selected_scores):
    print(f"Feature: {feature}, Score: {score}")
# Out:
# Selected top-k features based on ANOVA F-test:
# Feature: MI_dir_L5_weight, Score: 166820.37373593915
# Feature: MI_dir_L5_mean, Score: 185649.25833619214
# Feature: MI_dir_L5_variance, Score: 131595.52628130594
# Feature: MI_dir_L3_weight, Score: 282309.9483582427
# Feature: MI_dir_L3_mean, Score: 309945.2023079768
# Feature: MI_dir_L3_variance, Score: 284651.38602857804
# Feature: MI_dir_L1_weight, Score: 583230.4898218919
# Feature: MI_dir_L1_mean, Score: 655735.6975560008
# Feature: MI_dir_L1_variance, Score: 1035797.599264336
# Feature: MI_dir_L0.1_weight, Score: 478513.80181818
# Feature: MI_dir_L0.1_mean, Score: 1133120.8385615535
# Feature: MI_dir_L0.1_variance, Score: 1848336.0302287668
# Feature: MI_dir_L0.01_weight, Score: 92989.37199539198
# Feature: MI_dir_L0.01_mean, Score: 1483231.6048324744
# Feature: MI_dir_L0.01_variance, Score: 1798691.0071376644
# Feature: H_L5_weight, Score: 166820.37373593633
# Feature: H_L5_mean, Score: 185649.25833629616
# Feature: H_L5_variance, Score: 131595.52628130544
# Feature: H_L3_weight, Score: 282309.94835552
# Feature: H_L3_mean, Score: 309945.2025770662
# Feature: H_L3_variance, Score: 284651.38602770865
# Feature: H_L1_weight, Score: 583230.4879344678
# Feature: H_L1_mean, Score: 655736.8907276036
# Feature: H_L1_variance, Score: 1035797.6000113488
# Feature: H_L0.1_weight, Score: 478513.7915511707
# Feature: H_L0.1_mean, Score: 1134070.190357434
# Feature: H_L0.1_variance, Score: 1848297.8877163902
# Feature: H_L0.01_weight, Score: 92989.37036410464
# Feature: H_L0.01_mean, Score: 1487874.209732386
# Feature: H_L0.01_variance, Score: 1798706.098940838
# Feature: HH_L5_weight, Score: 108752.85322620586
# Feature: HH_L5_mean, Score: 42209.034902582694
# Feature: HH_L3_weight, Score: 116755.00468485666
# Feature: HH_L3_mean, Score: 42216.66644096772
# Feature: HH_L1_weight, Score: 121905.68680758637
# Feature: HH_L1_mean, Score: 42233.03264066539
# Feature: HH_L0.1_weight, Score: 86477.48793926377
# Feature: HH_L0.1_mean, Score: 42279.23114246488
# Feature: HH_L0.01_mean, Score: 42289.467635057605
# Feature: HH_jit_L5_weight, Score: 108752.85322620545
# Feature: HH_jit_L5_mean, Score: 41525.34555432403
# Feature: HH_jit_L3_weight, Score: 116755.0046848569
# Feature: HH_jit_L3_mean, Score: 41535.35892988148
# Feature: HH_jit_L1_weight, Score: 121905.68680758766
# Feature: HH_jit_L1_mean, Score: 42193.415940129824
# Feature: HH_jit_L0.1_weight, Score: 86477.48793926521
# Feature: HH_jit_L0.1_mean, Score: 46371.946204647225
# Feature: HH_jit_L0.1_variance, Score: 44015.45839132725
# Feature: HH_jit_L0.01_mean, Score: 47666.1584318017
# Feature: HH_jit_L0.01_variance, Score: 47201.195059323385
# Feature: HpHp_L5_mean, Score: 42163.27019184276
# Feature: HpHp_L3_mean, Score: 42166.695328763264
# Feature: HpHp_L1_weight, Score: 40745.28932020762
# Feature: HpHp_L1_mean, Score: 42172.06260080798
# Feature: HpHp_L1_magnitude, Score: 37962.465954935105
# Feature: HpHp_L0.1_weight, Score: 44440.15552254578
# Feature: HpHp_L0.1_mean, Score: 42167.8342793498
# Feature: HpHp_L0.1_magnitude, Score: 38387.54887115578
# Feature: HpHp_L0.01_mean, Score: 42174.13034953433
# Feature: HpHp_L0.01_magnitude, Score: 38668.51124431401

# %%
# Create a DataFrame with selected features
X_selected_dfA = pd.DataFrame(X_selected_A, columns=selected_feature_names)

selected_data_A = pd.concat([X_selected_dfA, Y.reset_index(drop=True)], axis=1)

# %%
print("\nDataFrame with selected features and target label:")
selected_data_A.head()
# Out:
# DataFrame with selected features and target label:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000001            0.000035          1.000027
# 1         71.808710      404.291170        51543.428265        125.281699
# 2         99.098462      539.163878         7092.667081        177.665688
# 3          1.000000       60.000000            0.000000          1.000000
# 4         72.901290       74.020851            0.499986         83.915628
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.001022            0.038818          1.029957       61.105252
# 1      424.867801        47116.181526        422.828931      417.754720
# 2      511.709702        19081.745825        558.049103      450.544525
# 3       60.000000            0.000000          1.000000       60.000000
# 4       74.060985            1.470257        120.945040       74.462130
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L3_mean  HpHp_L1_weight  \
# 0           40.777976            2.358867  ...          60.0        1.000000
# 1        48742.392108         1449.489396  ...         554.0      306.212643
# 2        40388.210513         5607.736776  ...         554.0      441.143118
# 3            0.000000            1.000000  ...          60.0        1.000000
# 4          207.762615         1042.124205  ...          74.0        1.017292
#
#    HpHp_L1_mean  HpHp_L1_magnitude  HpHp_L0.1_weight  HpHp_L0.1_mean  \
# 0          60.0          84.852814          1.157953            60.0
# 1         554.0         554.000000       1029.484938           554.0
# 2         554.0         554.000000       4032.028567           554.0
# 3          60.0          60.000000          1.000000            60.0
# 4          74.0          74.000000          2.193567            74.0
#
#    HpHp_L0.1_magnitude  HpHp_L0.01_mean  HpHp_L0.01_magnitude            type
# 0            84.852814             60.0             84.852814          benign
# 1           554.000000            554.0            554.000000  mirai_udpplain
# 2           554.000000            554.0            554.000000  mirai_udpplain
# 3            60.000000             60.0             60.000000      gafgyt_tcp
# 4            74.000000             74.0             74.000000     gafgyt_scan
#
# [5 rows x 61 columns]

# %% [markdown]
# **Split learning Model using pearson ANOVA-F based feature selection**

# %%
# Convert application names to numbers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %%
print(sorted(Counter(Y).items()))
# Out:
# [('benign', 24177), ('gafgyt_combo', 29780), ('gafgyt_junk', 28240), ('gafgyt_scan', 29210), ('gafgyt_tcp', 28532), ('gafgyt_udp', 31328), ('mirai_ack', 31407), ('mirai_scan', 22704), ('mirai_syn', 36758), ('mirai_udp', 31580), ('mirai_udpplain', 28291)]

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_selected_dfA, encoded_Y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
print(sorted(Counter(encoded_Y).items()))
# Out:
# [(0, 24177), (1, 29780), (2, 28240), (3, 29210), (4, 28532), (5, 31328), (6, 31407), (7, 22704), (8, 36758), (9, 31580), (10, 28291)]

# %%
print(sorted(Counter(y_resampled).items()))
# Out:
# [(0, 36758), (1, 36758), (2, 36758), (3, 36758), (4, 36758), (5, 36758), (6, 36758), (7, 36758), (8, 36758), (9, 36758), (10, 36758)]

# %%
encoded_Y[1:10]
# Out:
# array([10, 10,  4,  3,  9, 10,  8,  2,  1])

# %%
X_resampled.shape
# Out:
# (404338, 60)

# %%
 y_resampled.shape
# Out:
# (404338,)

# %%
#split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test,= train_test_split(X_resampled, y_resampled, train_size = 0.70, random_state=100)

# %%
# Data Transformation to Reduce Skewness
power_transformer = PowerTransformer(method='yeo-johnson')
X_train_transformed = power_transformer.fit_transform(X_train)
X_test_transformed = power_transformer.transform(X_test)

# %%
# Standard Scaling After Transformation
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_transformed)
X_test_scaled = scaler.transform(X_test_transformed)

# %%
y_train=tf.keras.utils.to_categorical(y_train, num_classes=11)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=11)  # One-hot encoding for test labels

# %%
# Updated Server Code
import socket
import pickle
import zlib
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import threading

# Server-side model
def create_server_model():
    model = Sequential([
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(11, activation='softmax'),  # Adjust number of classes as needed
    ])
    model.compile(optimizer=Adam(learning_rate=0.01),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Deserialize and decompress data using pickle
def deserialize_data(data):
    return pickle.loads(zlib.decompress(data))

# Create a tf.function outside the training loop to avoid retracing
@tf.function
def train_step(server_model, x_batch, y_batch, optimizer):
    with tf.GradientTape() as tape:
        logits = server_model(x_batch, training=True)
        loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_batch, logits))
    gradients = tape.gradient(loss, server_model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, server_model.trainable_variables))
    return loss

# Server function
def start_server(host='127.0.0.1', port=65432):
    server_model = create_server_model()
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server_socket.bind((host, port))
    server_socket.listen(1)
    print("Server waiting for connection...")
    conn, addr = server_socket.accept()
    print(f"Connected to client: {addr}")

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

    while True:
        try:
            # Receive header indicating batch size
            header = conn.recv(8)
            if not header:
                break
            data_size = int(header.decode('utf-8').strip())

            # Receive the batch data
            data = b""
            while len(data) < data_size:
                packet = conn.recv(4096)
                if not packet:
                    break
                data += packet

            # Deserialize the data
            intermediate_output, labels = deserialize_data(data)

            # Perform forward pass and backpropagation on batch
            batch_loss = train_step(server_model, np.array(intermediate_output), np.array(labels), optimizer)

            # Send back loss and correct predictions count
            correct_predictions = int(np.sum(np.argmax(server_model(np.array(intermediate_output)), axis=1) == np.argmax(labels, axis=1)))
            response = f"{batch_loss:.4f},{correct_predictions}"
            conn.sendall(f"{len(response):08}".encode('utf-8'))
            conn.sendall(response.encode('utf-8'))

        except Exception as e:
            print(f"Error: {e}")
            break

    # Evaluate test data in batches
    print("Evaluating test data...")
    header = conn.recv(8)
    while header:
        test_data_size = int(header.decode('utf-8').strip())
        test_data = b""
        while len(test_data) < test_data_size:
            packet = conn.recv(4096)
            if not packet:
                break
            test_data += packet

        # Deserialize the test data
        test_intermediate, test_labels = deserialize_data(test_data)

        # Calculate correct predictions for the batch
        correct_predictions = int(np.sum(np.argmax(server_model(np.array(test_intermediate)), axis=1) == np.argmax(test_labels, axis=1)))
        response = f"{correct_predictions}"
        conn.sendall(f"{len(response):08}".encode('utf-8'))
        conn.sendall(response.encode('utf-8'))



        header = conn.recv(8)

    conn.close()
    server_socket.close()
    print("Server connection closed.")

server_thread = threading.Thread(target=start_server)
server_thread.start()
# Out:
# Server waiting for connection...

# %%
# Updated Client Code
import socket
import pickle
import zlib
import time
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Client-side model
def create_client_model():
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(60, 1)),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
    ])
    return model

# Serialize and compress data using pickle
def serialize_data(data):
    return zlib.compress(pickle.dumps(data))

# Client function
def start_client(host='127.0.0.1', port=65432):
    client_model = create_client_model()
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    client_socket.connect((host, port))
    print("Connected to server!")

    batch_size = 512
    epochs = 1
    total_batches = int(np.ceil(X_train_scaled.shape[0] / batch_size))

    start_time = time.time()

    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        epoch_loss = 0
        correct_predictions = 0
        total_samples = 0

        for batch_index, i in enumerate(range(0, X_train_scaled.shape[0], batch_size), start=1):
            x_batch = X_train_scaled[i:min(i + batch_size, X_train_scaled.shape[0])]
            y_batch = y_train[i:min(i + batch_size, y_train.shape[0])]

            # Forward pass to get intermediate activations
            intermediate_output = client_model(x_batch, training=True).numpy()

            # Serialize and send data
            data = serialize_data((intermediate_output.tolist(), y_batch.tolist()))
            try:
                client_socket.sendall(f"{len(data):08}".encode('utf-8'))
                client_socket.sendall(data)
            except socket.error as e:
                print(f"Socket error: {e}")
                client_socket.close()
                return

            # Receive server response
            response_header = client_socket.recv(8)
            response_size = int(response_header.decode('utf-8').strip())
            response = client_socket.recv(response_size)
            server_loss, batch_correct = map(float, response.decode('utf-8').split(','))

            # Update statistics
            epoch_loss += server_loss
            correct_predictions += batch_correct
            total_samples += x_batch.shape[0]

            # Display batch progress
            progress = (batch_index / total_batches) * 100
            print(f"\rBatch {batch_index}/{total_batches} - Progress: {progress:.2f}% - Loss: {server_loss:.4f}", end="")

        training_accuracy = correct_predictions / total_samples
        print(f"\nEpoch {epoch + 1} completed: Avg Loss = {epoch_loss / total_batches:.4f}, "
              f"Training Accuracy = {training_accuracy:.4f}")

    total_training_time = time.time() - start_time
    print(f"\nTraining completed in {total_training_time:.2f} seconds.")

    # Evaluate testing accuracy in batches
    print("Evaluating on test data...")
    test_batch_size = 512  # Larger batch size for efficient testing
    total_test_batches = int(np.ceil(X_test_scaled.shape[0] / test_batch_size))
    correct_predictions = 0
    total_samples = 0

    for i in range(0, X_test_scaled.shape[0], test_batch_size):
        x_test_batch = X_test_scaled[i:min(i + test_batch_size, X_test_scaled.shape[0])]
        y_test_batch = y_test[i:min(i + test_batch_size, y_test.shape[0])]

        test_intermediate = client_model.predict(x_test_batch, verbose=0)
        test_data = serialize_data((test_intermediate.tolist(), y_test_batch.tolist()))

        client_socket.sendall(f"{len(test_data):08}".encode('utf-8'))
        client_socket.sendall(test_data)

        # Receive test batch accuracy
        test_accuracy_response = client_socket.recv(8)
        test_accuracy_size = int(test_accuracy_response.decode('utf-8').strip())
        test_accuracy_data = client_socket.recv(test_accuracy_size)
        batch_correct = int(test_accuracy_data.decode('utf-8'))


        correct_predictions += batch_correct
        total_samples += x_test_batch.shape[0]

    test_accuracy = correct_predictions / total_samples
    print(f"Testing Accuracy: {test_accuracy:.4f}")

    client_socket.close()
    print("Client connection closed.")

start_client()
# Out:
# Connected to server!Connected to client: ('127.0.0.1', 56262)
#
#
# Epoch 1/1
# Evaluating test data...
# Server connection closed.
# Batch 553/553 - Progress: 100.00% - Loss: 0.2549
# Epoch 1 completed: Avg Loss = 0.3569, Training Accuracy = 0.8089
#
# Training completed in 496.79 seconds.
# Evaluating on test data...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-6fd8309c1ceb> in <cell line: 123>()
#     121     print("Client connection closed.")
#     122
# --> 123 start_client()
#
# <ipython-input-45-6fd8309c1ceb> in start_client(host, port)
#     109         test_accuracy_size = int(test_accuracy_response.decode('utf-8').strip())
#     110         test_accuracy_data = client_socket.recv(test_accuracy_size).decode('utf-8')  # Decode response as string
# --> 111         batch_correct = float(test_accuracy_data)  # Convert accuracy to float
#     112         #print(f"Testing Accuracy: {test_accuracy:.4f}")
#     113
#
# ValueError: could not convert string to float: '0.2838,431'

# %%
import socket
import pickle
import zlib
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
import threading

# Server-side model
def create_server_model():
    model = Sequential([
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(11, activation='softmax'),  # Adjust classes if needed
    ])
    model.compile(optimizer=Adam(learning_rate=0.01),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# Deserialize and decompress data
def deserialize_data(data):
    return pickle.loads(zlib.decompress(data))

# Server function
def start_server(host='127.0.0.1', port=65437):
    server_model = create_server_model()
    server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server_socket.bind((host, port))
    server_socket.listen(1)
    print("Server waiting for connection...")
    conn, addr = server_socket.accept()
    print(f"Connected to client: {addr}")

    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

    while True:
        try:
            # Receive header indicating batch size
            header = conn.recv(8)
            if not header:
                break
            data_size = int(header.decode('utf-8').strip())


            # If a special flag (e.g., -1) is sent, switch to evaluation
            if data_size == -1:
              print("Switching to evaluation phase...")
              break

            # Receive the batch data
            data = b""
            while len(data) < data_size:
                packet = conn.recv(4096)
                if not packet:
                    break
                data += packet

            # Deserialize the data
            intermediate_output, labels = deserialize_data(data)

            # Perform forward pass and backpropagation on batch
            with tf.GradientTape() as tape:
                logits = server_model(np.array(intermediate_output), training=True)
                loss = tf.reduce_mean(
                    tf.keras.losses.categorical_crossentropy(np.array(labels), logits)
                )
            gradients = tape.gradient(loss, server_model.trainable_variables)
            optimizer.apply_gradients(zip(gradients, server_model.trainable_variables))

            correct_predictions = int(np.sum(
                np.argmax(logits.numpy(), axis=1) == np.argmax(labels, axis=1)
            ))
            response = f"{loss.numpy():.4f},{correct_predictions}"
            conn.sendall(f"{len(response):08}".encode('utf-8'))
            conn.sendall(response.encode('utf-8'))

        except Exception as e:
            print(f"Error: {e}")
            break

    # Handle test evaluation
    print("Evaluating test data...")
    while True:
        header = conn.recv(8)
        if not header:
            break
        test_data_size = int(header.decode('utf-8').strip())
        test_data = b""
        while len(test_data) < test_data_size:
            packet = conn.recv(4096)
            if not packet:
                break
            test_data += packet

        test_intermediate, test_labels = deserialize_data(test_data)
        logits = server_model(np.array(test_intermediate), training=False)
        correct_predictions = int(np.sum(
            np.argmax(logits.numpy(), axis=1) == np.argmax(test_labels, axis=1)
        ))
        response = f"{correct_predictions}"
        conn.sendall(f"{len(response):08}".encode('utf-8'))
        conn.sendall(response.encode('utf-8'))

    conn.close()
    server_socket.close()
    print("Server connection closed.")

server_thread = threading.Thread(target=start_server)
server_thread.start()
# Out:
# Server waiting for connection...

# %%
import socket
import pickle
import zlib
import time
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# Client-side model
def create_client_model():
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=(60, 1)),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
    ])
    return model

# Serialize and compress data using pickle
def serialize_data(data):
    return zlib.compress(pickle.dumps(data))

# Client function
def start_client(host='127.0.0.1', port=65437):
    client_model = create_client_model()
    client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    client_socket.connect((host, port))
    print("Connected to server!")

    batch_size = 128
    epochs = 1
    total_batches = int(np.ceil(X_train_scaled.shape[0] / batch_size))

    print("\nStarting Training...")
    start_time = time.time()

    for epoch in range(epochs):
        print(f"\nEpoch {epoch + 1}/{epochs}")
        epoch_loss = 0
        correct_predictions = 0
        total_samples = 0

        for batch_index, i in enumerate(range(0, X_train_scaled.shape[0], batch_size), start=1):
            x_batch = X_train_scaled[i:min(i + batch_size, X_train_scaled.shape[0])]
            y_batch = y_train[i:min(i + batch_size, y_train.shape[0])]

            # Forward pass to get intermediate activations
            intermediate_output = client_model(x_batch, training=True).numpy()

            # Serialize and send data
            data = serialize_data((intermediate_output.tolist(), y_batch.tolist()))
            client_socket.sendall(f"{len(data):08}".encode('utf-8'))
            client_socket.sendall(data)

            # Receive server response
            response_header = client_socket.recv(8)
            response_size = int(response_header.decode('utf-8').strip())
            response = client_socket.recv(response_size)
            server_loss, batch_correct = map(float, response.decode('utf-8').split(','))

            # Update statistics
            epoch_loss += server_loss
            correct_predictions += batch_correct
            total_samples += x_batch.shape[0]

            # Display batch progress
            progress = (batch_index / total_batches) * 100
            print(f"\rBatch {batch_index}/{total_batches} - Progress: {progress:.2f}% - Loss: {server_loss:.4f}", end="")

        training_accuracy = correct_predictions / total_samples
        print(f"\nEpoch {epoch + 1} completed: Avg Loss = {epoch_loss / total_batches:.4f}, "
              f"Training Accuracy = {training_accuracy:.4f}")

    total_training_time = time.time() - start_time
    print(f"\nTraining completed in {total_training_time:.2f} seconds.")

    # Signal the server to switch to evaluation mode
    client_socket.sendall(f"{-1:08}".encode('utf-8'))
    print("Training complete. Signaled server to start evaluation.")

    # Evaluate testing accuracy in batches
    print("\nEvaluating on test data...")
    test_batch_size = 512  # Larger batch size for efficient testing
    total_test_batches = int(np.ceil(X_test_scaled.shape[0] / test_batch_size))
    correct_predictions = 0
    total_samples = 0

    for i in range(0, X_test_scaled.shape[0], test_batch_size):
        x_test_batch = X_test_scaled[i:min(i + test_batch_size, X_test_scaled.shape[0])]
        y_test_batch = y_test[i:min(i + test_batch_size, y_test.shape[0])]

        test_intermediate = client_model.predict(x_test_batch, verbose=0)
        test_data = serialize_data((test_intermediate.tolist(), y_test_batch.tolist()))

        client_socket.sendall(f"{len(test_data):08}".encode('utf-8'))
        client_socket.sendall(test_data)

        # Receive test batch accuracy
        test_accuracy_response = client_socket.recv(8)
        test_accuracy_size = int(test_accuracy_response.decode('utf-8').strip())
        test_accuracy_data = client_socket.recv(test_accuracy_size)
        batch_correct = int(test_accuracy_data.decode('utf-8'))

        correct_predictions += batch_correct
        total_samples += x_test_batch.shape[0]

    test_accuracy = correct_predictions / total_samples
    print(f"\nTesting completed: Testing Accuracy = {test_accuracy:.4f}")

    client_socket.close()
    print("\nClient connection closed.")

# Start the client
start_client()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Connected to server!Connected to client: ('127.0.0.1', 51948)
#
#
# Starting Training...
#
# Epoch 1/1
# Batch 2212/2212 - Progress: 100.00% - Loss: 0.1755
# Epoch 1 completed: Avg Loss = 0.3115, Training Accuracy = 0.8213
#
# Training completed in 495.36 seconds.
# Training complete. Signaled server to start evaluation.
#
# Evaluating on test data...
# Switching to evaluation phase...
# Evaluating test data...
#
# Testing completed: Testing Accuracy = 0.8358
#
# Client connection closed.
# Server connection closed.
